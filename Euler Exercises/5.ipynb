# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(1,100000000000):
    if all(i % x == 0 for x in range(1,21)):
        print('We have found our lucky boy:', i)
        break

# %% [markdown]
# It works! but no works good!!! no no !
#
# ChatGPT says:

# %%
import math

# Function to calculate the LCM of two numbers
def lcm(a, b):
    return abs(a * b) // math.gcd(a, b)

# Calculate the LCM of all numbers from 1 to 20
lcm_all = 1
for i in range(1, 21):
    lcm_all = lcm(lcm_all, i)

print('The smallest number divisible by all numbers from 1 to 20 is:', lcm_all)

# %% [markdown]
# ![image.png](attachment:image.png)
